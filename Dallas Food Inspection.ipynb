# %%
# import required library # 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as xls

# %%
# import the dataset #

df = pd.read_csv('C:/Users/User/Downloads/Food Inspection/Dallas.csv')
df.head()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (91,93,94,95,97,98,99,101,102,103,105,106,107,109,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                    Restaurant Name Inspection Type Inspection Date  \
# 0                   MICKLE CHICKEN         Routine      10/30/2019
# 1            TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2             BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3            CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4  PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
#
#    Inspection Score  Street Number  Street Name Street Direction Street Type  \
# 0               100           3203  CAMP WISDOM                W          RD
# 1               100           2380        FIELD                N          ST
# ...

# %%
df.shape
# Out:
# (70492, 114)

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Inspection Type', 'Inspection Date',
#        'Inspection Score', 'Street Number', 'Street Name', 'Street Direction',
#        'Street Type', 'Street Unit', 'Street Address',
#        ...
#        'Violation Points - 24', 'Violation Detail - 24', 'Violation Memo - 24',
#        'Violation Description - 25', 'Violation Points - 25',
#        'Violation Detail - 25', 'Violation Memo - 25', 'Inspection Month',
#        'Inspection Year', 'Lat Long Location'],
#       dtype='object', length=114)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70492 entries, 0 to 70491
# Columns: 114 entries, Restaurant Name to Lat Long Location
# dtypes: float64(25), int64(2), object(87)
# memory usage: 61.3+ MB

# %%
# remove null values from restaurant coloum dataset #

df[df['Restaurant Name'].notnull()]
# Out:
#                        Restaurant Name Inspection Type Inspection Date  \
# 0                       MICKLE CHICKEN         Routine      10/30/2019
# 1                TOM THUMB - JUICE BAR         Routine      04/08/2020
# 2                 BROOKDALE WHITE ROCK         Routine      07/29/2020
# 3                CHURCH'S CHICKEN #201         Routine      09/14/2020
# 4      PEAK PREPARATORY-PRIMARY SCHOOL         Routine      04/25/2017
# ...                                ...             ...             ...
# 70487            CHARLIE'S STAR LOUNGE         Routine      02/28/2023
# 70488          SAM'S CLUB #8248/BAKERY         Routine      03/10/2023
# 70489                     MEXICO LINDO         Routine      02/21/2023
# 70490            HIDEAWAY ON HENDERSON         Routine      02/19/2023
# 70491                  MARIA'S GROCERY         Routine      02/26/2023
#
#        Inspection Score  Street Number  Street Name Street Direction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70492 entries, 0 to 70491
# Columns: 114 entries, Restaurant Name to Lat Long Location
# dtypes: float64(25), int64(2), object(87)
# memory usage: 61.3+ MB

# %%
# export the dataset as excel file # 

excel_file = pd.ExcelWriter("Dallas Food Inspection Present.xlsx")
df.to_excel(excel_file)
excel_file.save()
